# %% [markdown]
# # 📘 Introducción a Python
# ## Notebook 2 – Estructuras de control
#
# **Objetivos de aprendizaje**
# - Tomar decisiones con `if/elif/else` (incluye validación y ramificación múltiple).
# - Repetir tareas con `for`, `while`, `range` y bucles anidados.
# - Controlar el flujo con `break`, `continue`, `else` en bucles.
# - Reconocer patrones frecuentes (contadores, acumuladores, búsqueda, menú).
# - Diseñar pequeños programas interactivos y robustos.
#
# > Consejo: empieza por la versión más simple que funcione y **refactoriza**.

# %% [markdown]
# ## 1. Recordatorio: truthiness y decisiones
# En Python, en contextos booleanos, `0`, `''`, `[]`, `{}`, `set()` y `None` se consideran `False`; el resto `True`.

# %%
datos = ['', 'hola', 0, 1, [], [1], None]
for d in datos:
    if d:
        print(repr(d), '=> True')
    else:
        print(repr(d), '=> False')

# %% [markdown]
# ## 2. Condicionales `if / elif / else`
# Estructura básica para **tomar decisiones**. Añadimos validación de entradas.

# %%
raw = input('Nota (0-10): ').strip()
try:
    nota = float(raw)
    if not 0 <= nota <= 10:
        print('La nota debe estar entre 0 y 10')
    elif nota >= 9:
        print('Sobresaliente')
    elif nota >= 7:
        print('Notable')
    elif nota >= 5:
        print('Aprobado')
    else:
        print('Suspenso')
except ValueError:
    print('Introduce un número válido')

# %% [markdown]
# ### Comparaciones encadenadas y operadores lógicos
# Python permite escribir `0 <= x <= 10`. Úsalas para legibilidad.

# %%
x = 7
print(0 <= x <= 10)  # True
print((x >= 0) and (x <= 10))  # equivalente

# %% [markdown]
# ## 3. Bucles `for` y `range()`
# `range(inicio, fin, paso)` genera secuencias de enteros perezosamente.
# Itera colecciones directamente (listas, cadenas, diccionarios).

# %%
# Recorre un rango y una cadena
for i in range(2, 10, 2):
    print('par:', i)

for c in 'Python':
    print(c, end=' ')
print()

# %% [markdown]
# ### Iterar diccionarios con `.items()`

# %%
persona = {'nombre':'Ada', 'edad':36, 'pais':'UK'}
for clave, valor in persona.items():
    print(clave, '->', valor)

# %% [markdown]
# ## 4. Bucle `while` y control de flujo (`break`, `continue`, `else`)
# - `break` termina el bucle.
# - `continue` salta a la siguiente iteración.
# - La cláusula `else` de un bucle se ejecuta si **no** se usó `break`.

# %%
# Ejemplo: buscar el primer divisible por 7 entre 1..50
for n in range(1, 51):
    if n % 7 == 0:
        print('Primer divisible por 7:', n)
        break
else:
    print('No se encontró')

# Saltar vocales
def sin_vocales(texto):
    res = ''
    for c in texto:
        if c.lower() in 'aeiou':
            continue
        res += c
    return res

print(sin_vocales('Control de Flujo'))

# %% [markdown]
# ## 5. Bucles anidados y patrones frecuentes
# **Patrones**
# - **Contador**: cuántas veces ocurre algo.
# - **Acumulador**: sumar valores.
# - **Búsqueda**: encontrar un elemento.
# - **Máximo/Mínimo**: rastrear el mejor/peor.
# - **Menú**: estructura de interacción con el usuario.

# %%
# Contador y acumulador
nums = [3, 5, 7, 2, 7, 7]
conteo_7 = 0
suma = 0
for n in nums:
    if n == 7:
        conteo_7 += 1
    suma += n
print('veces 7:', conteo_7, '| suma:', suma)

# Máximo manual (sin max())
mayor = None
for n in nums:
    if (mayor is None) or (n > mayor):
        mayor = n
print('mayor:', mayor)

# Tabla 3x3 con bucles anidados
for fila in range(1, 4):
    for col in range(1, 4):
        print(f'({fila},{col})', end=' ')
    print()

# %% [markdown]
# ## 6. Entrada robusta: patrón `pedir_int` / `pedir_float`
# Centraliza la validación para **no duplicar código**.

# %%
def pedir_int(msg, minimo=None, maximo=None):
    while True:
        raw = input(msg).strip()
        try:
            n = int(raw)
            if (minimo is not None and n < minimo) or (maximo is not None and n > maximo):
                print(f'Introduce un entero entre {minimo} y {maximo}')
                continue
            return n
        except ValueError:
            print('Introduce un entero válido')

edad = pedir_int('Edad (0-120): ', 0, 120)
print('Edad válida:', edad)

# %% [markdown]
# ## 7. Actividades guiadas (con pistas y criterios)
# ### Actividad 1 — FizzBuzz
# **Enunciado**: Imprime números del 1 al 50, pero:
# - si es múltiplo de 3, imprime `Fizz`;
# - si es múltiplo de 5, imprime `Buzz`;
# - si es múltiplo de ambos, `FizzBuzz`.
#
# **Pistas**: `%` y orden de condiciones.
#
# **Criterios**: salida correcta y código legible.

# %%
# 👇 Tu solución

# %% [markdown]
# ### Actividad 2 — Adivina el número
# **Enunciado**: El programa elige un número aleatorio entre 1 y 20. Tienes 5 intentos para acertarlo.
#
# **Pistas**: `random.randint(1,20)`, `while` con contador de intentos, dar pistas de *mayor/menor*.
#
# **Criterios**: controla entradas inválidas y muestra mensajes claros.

# %%
# 👇 Tu solución

# %% [markdown]
# ### Actividad 3 — Producto del 1 hasta *n*
#
# **Enunciado**:
# Pide un número entero `n` (mayor o igual que 0) y calcula el **producto de todos los números desde 1 hasta n**.
#
# Por ejemplo:
#
# - Si `n = 4`, el programa debe calcular: `1 * 2 * 3 * 4 = 24`
# - Si `n = 0`, por definición el resultado será `1`
#
# **Pistas**:
# - Usa una variable acumuladora, por ejemplo `producto = 1`.
# - Recorre los números del 1 al `n` con un `while` (o un `for` si ya te ves cómodo).
# - En cada vuelta multiplica el acumulador por el número actual.
#
# **Criterios**:
# - No aceptar números negativos.
# - Usar solo números enteros.
# - Mostrar el resultado al final de forma clara.

# %%
# 👇 Tu solución

# %% [markdown]
# ### Actividad 4 — Tabla de multiplicar
# **Enunciado**: Pide un número y muestra su tabla del 1 al 10.
#
# **Pistas**: `for` y `range(1, 11)`.
#
# **Criterios**: formato alineado.

# %%
# 👇 Tu solución

# %% [markdown]
# ## 8. Mini-proyecto — Menú interactivo (nivel intermedio)
# **Objetivo**: Construir un menú que permita ejecutar varias utilidades.
#
# **Enunciado**:
# Implementa un programa con menú (opciones numeradas) que ofrezca:
# 1) **Calculadora** (suma/resta/multi/div) con validación y manejo de división por cero.
# 2) **Conversor de temperaturas** (C ↔ F).
# 3) **Generador de secuencias**: imprime pares/impares del 1..N o tabla de multiplicar.
# 4) **Salir**.
#
# **Pistas**: `while True`, `break` para salir, funciones para cada opción.
#
# **Criterios de logro**:
# - Entrada robusta.
# - Código modular (funciones).
# - Mensajes claros y formato cuidado.

# %%
# 👇 Tu solución del mini-proyecto

# %% [markdown]
# ## 9. Siguientes pasos
# En el próximo notebook profundizaremos en **estructuras de datos** (listas, tuplas, diccionarios, conjuntos) y veremos **comprensiones** para crear colecciones de forma compacta.
